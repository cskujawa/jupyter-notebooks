# %% [markdown]
# # LLaMa EULA
# To use the LLaMa model from HuggingFace I had to agree to a EULA, and approval is still pending

# %%
# Install transformers dependencies
# !pip install -qU transformers
# !pip install accelerate
# Had to add in the install tensorflow (which should already be installed in this container) with the [and-cuda] to get some extra functions out of it
# !pip install tensorflow[and-cuda]
import transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 63.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 59.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 56.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 87.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 59.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 53.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 63.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 64.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 61.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 59.7 MB/s eta 0:00:0000:0100:01
# ...

# %%
# Install Huggingface dependency and login using token
# !pip install --upgrade huggingface_hub
from huggingface_hub import login
login()
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
from transformers import LlamaForCausalLM, LlamaTokenizer

def run_llama_inference(model_name: str, prompt_text: str):
    # Load the tokenizer and model
    tokenizer = LlamaTokenizer.from_pretrained(model_name)
    model = LlamaForCausalLM.from_pretrained(model_name)

    # Encode the prompt text
    input_ids = tokenizer(prompt_text, return_tensors="pt").input_ids

    # Generate text using the model
    output = model.generate(input_ids, max_length=50, num_return_sequences=1)

    # Decode the generated text
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

    print(f"Generated Text: {generated_text}")

# Example usage
model_name = "meta-llama/Llama-2-7b"  # You can replace this with the specific LLaMa model you want to use
prompt_text = "Once upon a time"
run_llama_inference(model_name, prompt_text)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 22
#      20 model_name = "meta-llama/Llama-2-7b"  # You can replace this with the specific LLaMa model you want to use
#      21 prompt_text = "Once upon a time"
# ---> 22 run_llama_inference(model_name, prompt_text)
#
# Cell In[3], line 5, in run_llama_inference(model_name, prompt_text)
#       3 def run_llama_inference(model_name: str, prompt_text: str):
#       4     # Load the tokenizer and model
# ----> 5     tokenizer = LlamaTokenizer.from_pretrained(model_name)
#       6     model = LlamaForCausalLM.from_pretrained(model_name)
#       8     # Encode the prompt text
#
# ...
